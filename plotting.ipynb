# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['DejaVu Sans'],'size': 12})
rc('mathtext',**{'default':'regular'})
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
gnn_2p_range = [10, 20, 30, 50, 70, 100]

gnn_nc_2p_clue_F = [0.657833488850464, 0.657833488850464, 0.657833488850464, 0.657833488850464, 0.657833488850464, 0.657833488850464]
gnn_nc_2p_target_F = [0.709613324288395, 0.7814183663627319, 0.8552336878770943, 0.8923024450872056, 0.8965497444336143, 0.901496910968999]
gnn_nc_2p_reco_F = [0.7045536138850059, 0.7699524655659775, 0.8451234492252435, 0.8816242245216624, 0.88365755146593, 0.8875564380144716]

gnn_lp_2p_target_F = [0.8437354538062112, 0.8827909550411878, 0.8949147404605471, 0.896723513091889, 0.8984433591070247, 0.8984433591070247]
gnn_lp_2p_reco_F = [0.8415168841944893, 0.8799705030304544, 0.8912514787270778, 0.8933921037506163, 0.8939779159344413, 0.8887618163668993]

# %%
fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111)

# ax.plot(gnn_2p_range, (np.array(gnn_lc_2p_target_F) - np.array(gnn_nc_2p_clue_F)), '--s', label="LP target", c="#D55E00")
ax.plot(gnn_2p_range, (np.array(gnn_nc_2p_reco_F) - np.array(gnn_nc_2p_clue_F)), '-o', label="GNN NC", c="#D55E00")
ax.plot(gnn_2p_range, (np.array(gnn_lp_2p_reco_F) - np.array(gnn_nc_2p_clue_F)), '-v', label="GNN LP", c="#56B4E9")

ax.axhline(0.228, label="MLP baseline", c="lightgray", linestyle="--")

ax.legend()
ax.set_xlabel("Neighborhood radius (cm)")
ax.set_ylabel("$\Delta F_{0.5}$")
# ax.set_ylim((-0.1, 0.1))

fig.savefig(f'export/CloseByTwoPion-GNN-radius-plot.png', dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# %% [markdown]
# ## Pileup

# %%
gnn_PU_range = [3, 5, 10, 15]

gnn_nc_PU_clue_F = [0.697359457233105, 0.697359457233105, 0.697359457233105, 0.697359457233105]
gnn_nc_PU_target_F = [0.721990914206821, 0.7621395016497396, 0.7877936906702858, 0.7892889965449527]
gnn_nc_PU_reco_F = [0.7197781621135918, 0.7463869302532087, 0.7622167672908454, 0.7820292071899433]

# gnn_lp_PU_clue_F = [0.2660786195101392, 0.5618487610549607, 0.6503284712982198, 0.6974920132483364]
# gnn_lp_PU_target_F = [0.2919276870410676, 0.6258355186302973, 0.7396882199913862, 0.7894303922179595]
# gnn_lp_PU_reco_F = [0.2839844192276372, 0.603756619812702, 0.7209070767506977, 0.7746523994620464]

# larger net, 400 files
gnn_lp_PU_clue_F = [0.2660786195101392, 0.5618487610549607, 0.6503284712982198, 0.6974920132483364]
gnn_lp_PU_target_F = [0.2925245062036259, 0.631796889255891, 0.7530917443918212, 0.8020145508567055]
gnn_lp_PU_reco_F = [0.28307734475674334, 0.616571273678623, 0.7505698827151652, 0.7948727273697329]

# %%
fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111)

# ax.plot(gnn_PU_range, (np.array(gnn_lc_PU_target_F) - np.array(gnn_lc_PU_clue_F)), '-o', label="GNN NC", c="#56B4E9")
# ax.plot(gnn_PU_range, (np.array(gnn_lp_PU_target_F) - np.array(gnn_lp_PU_clue_F)), '--s', label="Target", c="#56B4E9")
ax.plot(gnn_PU_range, (np.array(gnn_nc_PU_reco_F) - np.array(gnn_nc_PU_clue_F)), '-s', label="GNN NC", c="#D55E00")
ax.plot(gnn_PU_range, (np.array(gnn_lp_PU_reco_F) - np.array(gnn_lp_PU_clue_F)), '-v', label="GNN LP", c="#56B4E9")

ax.axhline(0.073, label="MLP baseline", c="lightgray", linestyle="--")

ax.legend()
ax.set_xlabel("Neighborhood radius (cm)")
ax.set_ylabel("$\Delta F_{0.5}$")
# ax.set_ylim((-0.1, 0.1))

fig.savefig(f'export/CloseByPion200PU-GNN-radius-plot.png', dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# %%
print("Best PU LP:", max((np.array(gnn_lp_PU_reco_F) - np.array(gnn_lp_PU_clue_F))))
print("Best PU NC:", max((np.array(gnn_nc_PU_reco_F) - np.array(gnn_nc_PU_clue_F))))
# Out:
# Best PU LP: 0.10024141141694543
# Best PU NC: 0.08466974995683829

# %% [markdown]
# ## Multiparticle

# %%
gnn_MP_range = [5, 10, 20, 30]


# LP with Norm layer (5000 graphs)
gnn_MP_lp_clue = [0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
gnn_MP_lp_target = [0.5384628263859672, 0.6025392654121396, 0.5920900464142245, 0.5825359464438431]
gnn_MP_lp_reco = [0.5223763352150408, 0.5925567316424671, 0.6047396967353035, 0.6060942759227783]

# LP with Norm layer (2000 graphs)
# gnn_MP_lp_clue = [0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
# gnn_MP_lp_target = [0.5384628263859672, 0.6025392654121396, 0.5920900464142245, 0.5825359464438431]
# gnn_MP_lp_reco = [0.5160968484896499, 0.5744086376968782, 0.5813907527009021, 0.5832231504033826]

# LP without norm layer
# if this works, make sure to describe it (and rerun the other two datasets eval
#gnn_MP_lp_clue = [0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
#gnn_MP_lp_target = [0.5384628263859672, 0.6025392654121396, 0.5920900464142245, 0.5825359464438431]
#gnn_MP_lp_reco = [0.5090044308483728, 0.5546518677041486, 0.5594555038199234, 0.560433408772401]

# LP candidates (without allow_multi)
#[0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
#[0.5163919053100124, 0.5900391172620525, 0.6126152760328196, 0.6212816255254285]
#[0.491663189156878, 0.5303897934331483, 0.5429348061652325, 0.5458893897601225]


# 5f
# gnn_MP_nc_clue = [0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
# gnn_MP_nc_target = [0.5259644098162075, 0.6064421196483588, 0.6208185378572347, 0.6286151306406551]
# gnn_MP_nc_reco = [0.5478367544694712, 0.6141135325484113, 0.589112268293016, 0.6051785918763427]

# 3 layers, 10f
gnn_MP_nc_clue = [0.45468812367852296, 0.45468812367852296, 0.45468812367852296, 0.45468812367852296]
gnn_MP_nc_target = [0.5259644098162075, 0.6064421196483588, 0.6208185378572347, 0.6286151306406551]
gnn_MP_nc_reco = [0.5409682937473914, 0.6108236731056269, 0.6235436162880916, 0.6171658438392684]

# %%
fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111)

ax.plot(gnn_MP_range, (np.array(gnn_MP_nc_reco) - np.array(gnn_MP_nc_clue)), '-s', label="GNN NC", c="#D55E00")
ax.plot(gnn_MP_range, (np.array(gnn_MP_lp_reco) - np.array(gnn_MP_lp_clue)), '-v', label="GNN LP", c="#56B4E9")

ax.axhline(0.151, label="MLP baseline", c="lightgray", linestyle="--")

ax.legend()
ax.set_xlabel("Neighborhood radius (cm)")
ax.set_ylabel("$\Delta F_{0.5}$")
# ax.set_ylim((-0.1, 0.1))

fig.savefig(f'export/MultiParticle-GNN-radius-plot.png', dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# %%
max((np.array(gnn_MP_nc_reco) - np.array(gnn_MP_nc_clue)))
# Out:
# 0.16885549260956867

# %% [markdown]
# ### MLP PU results
#
# Reco 0.08252093900234114
# Naive 0.04353622488177655
# Target 0.09193837896962309
#
# --> very good, update the figure!
#
# {ds_name}-e5-radius-plot.png
#
# CLUE: [0.2660786195101392, 0.5618487610549607, 0.6503284712982198, 0.6974920132483364]
# Target: [0.2919276870410676, 0.6258355186302973, 0.7396882199913862, 0.7894303922179595]
# Reco: [0.29198701138042893, 0.6162043906814609, 0.7303545363084473, 0.7800129522506776]
