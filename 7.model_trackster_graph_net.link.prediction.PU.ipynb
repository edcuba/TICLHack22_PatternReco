# %% [markdown]
# # Graph net for link prediction
#
# Question: does including the neighborhood provide a benefit over the pairwise classification?

# %%
import numpy as np
import torch
import sys

import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR

from torch.utils.data import random_split
from torch_geometric.loader import DataLoader

import torch_geometric.nn as gnn

from reco.model import DynamicEdgeConvBlock

from reco.training import precision_recall_curve, roc_auc
from reco.loss import QualityFocalLoss
from reco.datasetPU import TracksterGraph


ds_name = "CloseByPion200P"

data_root = "data"
raw_dir = f"/Users/ecuba/data/{ds_name}"

data_root = "/mnt/ceph/users/ecuba/processed"
raw_dir = f"/mnt/ceph/users/ecuba/{ds_name}"

# %%
# CUDA Setup
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
ds = TracksterGraph(
    ds_name,
    data_root,
    raw_dir,
    N_FILES=200,
    radius=15,
    bigT_e_th=5,
    link_prediction=True,
    pileup=True,
)
ds
# Out:
# TracksterGraphPU(graphs=3811, nodes=169954, radius=15, bigT_e_th=5, lp)

# %%
ds_size = len(ds)
test_set_size = ds_size // 10
train_set_size = ds_size - test_set_size
train_set, test_set = random_split(ds, [train_set_size, test_set_size])
print(f"Train graphs: {len(train_set)}, Test graphs: {len(test_set)}, total: {ds_size}")

train_dl = DataLoader(train_set, batch_size=8, shuffle=True, drop_last=True)
test_dl = DataLoader(test_set, batch_size=8, shuffle=True, drop_last=True)
# Out:
# Train graphs: 3430, Test graphs: 381, total: 3811

# %%
class LinkPredictionNet(nn.Module):
    def __init__(self, input_dim, output_dim=1, dropout=0.2):
        super(LinkPredictionNet, self).__init__()
        # self.norm = gnn.LayerNorm(input_dim)
        
        hdim1 = 32
        hdim2 = 64
        hdim_fc = 128

        self.edgeconv1 = DynamicEdgeConvBlock(input_dim, hdim1, k=7)
        self.edgeconv2 = DynamicEdgeConvBlock(hdim1, hdim2, k=7)
        
        # Edge features from node embeddings for classification        
        self.nodenetwork = nn.Sequential(
            nn.Linear(2 * hdim2, hdim_fc),
            nn.Sigmoid(),
            nn.Dropout(dropout),
            nn.Linear(hdim_fc, output_dim),
        )

    def forward(self, X, edge_index, batch=None):
        H0 = X #self.norm(X, batch)
        H1 = self.edgeconv1(H0, batch=batch)
        H2 = self.edgeconv2(H1, batch=batch)
        
        H3 = H2

        src, dst = edge_index
        edges = torch.cat([H3[src], H3[dst]], dim=-1)
        return self.nodenetwork(edges).squeeze(-1)

# %%
def train_link_prediction(model, device, optimizer, loss_func, train_dl):
    train_loss = []
    model.train()

    for data in train_dl:
        data = data.to(device)
        optimizer.zero_grad()

        seg_pred = model(data.x, data.edge_index, batch=data.batch)        
        loss = loss_func(seg_pred, data.y)
        
        loss.backward()
        
        optimizer.step()
        train_loss.append(loss.item())

    return np.mean(train_loss)

# %%
@torch.no_grad()
def test_link_prediction(model, device, loss_func, test_dl):
    test_loss = []
    model.eval()
    for data in test_dl:
        data = data.to(device)
        seg_pred = model(data.x, data.edge_index, data.batch)
        loss = loss_func(seg_pred, data.y)
        test_loss.append(loss.item())

    return np.mean(test_loss)

# %%
model = LinkPredictionNet(input_dim=ds.data.x.shape[1])
epochs = 101
model_path = f"models/LinkPredictionNet.PnetL.ns.{epochs}e-{ds_name}.r{ds.RADIUS}.e{ds.bigT_e_th}.f{ds.N_FILES}.pt"

# %%
# %%script echo skipping
# # alpha - percentage of negative edges
# loss_func = QualityFocalLoss()
#
# model = model.to(device)
# optimizer = Adam(model.parameters(), lr=1e-3)
# scheduler = CosineAnnealingLR(optimizer, epochs, eta_min=1e-5)
#
# for epoch in range(epochs):
#
#     train_loss = train_link_prediction(
#         model,
#         device,
#         optimizer,
#         loss_func,
#         train_dl
#     )
#
#     scheduler.step()
#
#     if epoch % 2 == 0:
#         test_loss = test_link_prediction(model, device, loss_func, test_dl)
#         print(
#             f"Epoch {epoch}:\t train loss: {train_loss:.3f}\t validation loss: {test_loss:.3f}",
#             file=sys.stderr
#         )
#
# torch.save(model.state_dict(), model_path)
# print(model_path)
# Out:
# skipping

# %%
#%%script echo skipping
model.load_state_dict(torch.load(
    model_path,
    map_location=device
))
model = model.to(device)

# %%
#%%script echo skipping
print(roc_auc(model, device, test_dl))
precision_recall_curve(model, device, test_dl, focus_metric="fbeta", beta=0.5, step=3, truth_threshold=0.5)
# Out:
# 0.9445503680544018
# TP: 12064, TN: 18206, FP: 1175, FN: 3725
# TH: 0.52 precision: 0.911 recall: 0.764 fbeta: 0.877 b_acc: 0.852

# %% [markdown]
# --> overfits: need more data!!

# %% [markdown]
# ## Eval

# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np
from reco.data import get_event_data
from reco.evaluation import model_evaluation
from reco.dummy import DummyPleaser

file_name = f"{raw_dir}/new_ntuples_15643817_2.root"
cluster_data, trackster_data, simtrackster_data, assoc_data = get_event_data(file_name, pileup=True)

# %%
r_ranges = [3, 5, 10, 15]
results = []

max_events = 20
clue3D_F = []
target_F = []
model_reco_F = []
for r in r_ranges:
    print(f" --- Radius threshold: {r} ---")
    result = model_evaluation(
        cluster_data,
        trackster_data,
        simtrackster_data,
        assoc_data,
        model.to("cpu"),
        decision_th=0.5,
        radius=r,
        max_events=max_events,
        bigT_e_th=5,
        pileup=True,
        graph=True,
        link_prediction=True,
    )
    clue3D_F.append(np.sum(np.array(result["clue3d_to_sim"])[:,2]) / max_events)
    target_F.append(np.sum(np.array(result["target_to_sim"])[:,2]) / max_events)
    model_reco_F.append(np.sum(np.array(result["reco_to_sim"])[:,2]) / max_events)
# Out:
#  --- Radius threshold: 3 ---
# Event 0:
# 	clue3d_to_sim:	P: 0.836 R: 0.298 F: 0.614
# 	target_to_sim:	P: 0.818 R: 0.347 F: 0.643
# 	reco_to_sim:	P: 0.836 R: 0.298 F: 0.614
# 	|S| = 1 |T| = 2 |R| = 2
# Event 1:
# 	No data
# Event 2:
# 	clue3d_to_sim:	P: 0.970 R: 0.215 F: 0.569
# 	target_to_sim:	P: 0.971 R: 0.260 F: 0.627
# 	reco_to_sim:	P: 0.971 R: 0.247 F: 0.612
# 	|S| = 1 |T| = 2 |R| = 2
# Event 3:
# 	No data
# Event 4:
# 	No data
# Event 5:
# 	No data
# Event 6:
# 	clue3d_to_sim:	P: 0.971 R: 0.499 F: 0.816
# 	target_to_sim:	P: 0.964 R: 0.524 F: 0.825
# 	reco_to_sim:	P: 0.967 R: 0.502 F: 0.816
# 	|S| = 1 |T| = 4 |R| = 4
# Event 7:
# 	clue3d_to_sim:	P: 0.890 R: 0.022 F: 0.100
# 	target_to_sim:	P: 0.902 R: 0.023 F: 0.105
# 	reco_to_sim:	P: 0.902 R: 0.023 F: 0.105
# 	|S| = 1 |T| = 2 |R| = 2
# Event 8:
# 	clue3d_to_sim:	P: 0.881 R: 0.306 F: 0.640
# 	target_to_sim:	P: 0.867 R: 0.408 F: 0.708
# 	reco_to_sim:	P: 0.881 R: 0.399 F: 0.710
# 	|S| = 1 |T| = 1 |R| = 1
# Event 9:
# 	clue3d_to_sim:	P: 0.994 R: 0.095 F: 0.343
# 	target_to_sim:	P: 0.995 R: 0.138 F: 0.444
# 	reco_to_sim:	P: 0.994 R: 0.095 F: 0.343
# 	|S| = 1 |T| = 1 |R| = 1
# Event 10:
# 	No data
# Event 11:
# 	clue3d_to_sim:	P: 0.984 R: 0.677 F: 0.903
# 	target_to_sim:	P: 0.984 R: 0.686 F: 0.905
# 	reco_to_sim:	P: 0.984 R: 0.678 F: 0.903
# 	|S| = 1 |T| = 3 |R| = 3
# Event 12:
# 	clue3d_to_sim:	P: 0.744 R: 0.001 F: 0.005
# 	target_to_sim:	P: 0.794 R: 0.003 F: 0.016
# 	reco_to_sim:	P: 0.799 R: 0.003 F: 0.015
# 	|S| = 1 |T| = 2 |R| = 2
# Event 13:
# 	No data
# Event 14:
# 	No data
# Event 15:
# 	No data
# Event 16:
# 	clue3d_to_sim:	P: 0.986 R: 0.679 F: 0.904
# 	target_to_sim:	P: 0.984 R: 0.701 F: 0.910
# 	reco_to_sim:	P: 0.984 R: 0.701 F: 0.910
# 	|S| = 1 |T| = 1 |R| = 1
# Event 17:
# 	No data
# Event 18:
# 	No data
# Event 19:
# 	clue3d_to_sim:	P: 0.768 R: 0.153 F: 0.426
# 	target_to_sim:	P: 0.777 R: 0.401 F: 0.654
# 	reco_to_sim:	P: 0.777 R: 0.396 F: 0.652
# 	|S| = 1 |T| = 1 |R| = 1
# -----
# mean clue3d_to_sim:	P: 0.451 R: 0.147 F: 0.266
# mean target_to_sim:	P: 0.453 R: 0.174 F: 0.292
# mean reco_to_sim:	P: 0.455 R: 0.167 F: 0.284
# mean n_tracksters:	P: 0.500 R: 0.950 F: 0.950
#  --- Radius threshold: 5 ---
# Event 0:
# 	clue3d_to_sim:	P: 0.822 R: 0.307 F: 0.615
# 	target_to_sim:	P: 0.799 R: 0.527 F: 0.725
# 	reco_to_sim:	P: 0.823 R: 0.310 F: 0.619
# 	|S| = 1 |T| = 3 |R| = 5
# Event 1:
# 	clue3d_to_sim:	P: 0.999 R: 0.334 F: 0.715
# 	target_to_sim:	P: 0.996 R: 0.348 F: 0.726
# 	reco_to_sim:	P: 0.996 R: 0.348 F: 0.726
# 	|S| = 1 |T| = 2 |R| = 2
# Event 2:
# 	clue3d_to_sim:	P: 0.955 R: 0.221 F: 0.573
# 	target_to_sim:	P: 0.940 R: 0.375 F: 0.723
# 	reco_to_sim:	P: 0.953 R: 0.363 F: 0.719
# 	|S| = 1 |T| = 2 |R| = 2
# Event 3:
# 	clue3d_to_sim:	P: 0.741 R: 0.001 F: 0.007
# 	target_to_sim:	P: 0.741 R: 0.001 F: 0.007
# 	reco_to_sim:	P: 0.741 R: 0.001 F: 0.007
# 	|S| = 1 |T| = 1 |R| = 1
# Event 4:
# 	clue3d_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	target_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	reco_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	|S| = 1 |T| = 1 |R| = 1
# Event 5:
# 	No data
# Event 6:
# 	clue3d_to_sim:	P: 0.971 R: 0.499 F: 0.816
# 	target_to_sim:	P: 0.952 R: 0.616 F: 0.859
# 	reco_to_sim:	P: 0.962 R: 0.541 F: 0.832
# 	|S| = 1 |T| = 3 |R| = 3
# Event 7:
# 	clue3d_to_sim:	P: 0.974 R: 0.353 F: 0.720
# 	target_to_sim:	P: 0.966 R: 0.381 F: 0.739
# 	reco_to_sim:	P: 0.975 R: 0.377 F: 0.740
# 	|S| = 1 |T| = 3 |R| = 3
# Event 8:
# 	clue3d_to_sim:	P: 0.881 R: 0.306 F: 0.640
# 	target_to_sim:	P: 0.866 R: 0.434 F: 0.722
# 	reco_to_sim:	P: 0.881 R: 0.306 F: 0.640
# 	|S| = 1 |T| = 1 |R| = 2
# Event 9:
# 	clue3d_to_sim:	P: 0.994 R: 0.095 F: 0.343
# 	target_to_sim:	P: 0.994 R: 0.177 F: 0.517
# 	reco_to_sim:	P: 0.993 R: 0.127 F: 0.421
# 	|S| = 1 |T| = 1 |R| = 1
# Event 10:
# 	clue3d_to_sim:	P: 0.976 R: 0.576 F: 0.857
# 	target_to_sim:	P: 0.972 R: 0.634 F: 0.878
# 	reco_to_sim:	P: 0.972 R: 0.634 F: 0.878
# 	|S| = 1 |T| = 1 |R| = 1
# Event 11:
# 	clue3d_to_sim:	P: 0.957 R: 0.679 F: 0.885
# 	target_to_sim:	P: 0.950 R: 0.823 F: 0.921
# 	reco_to_sim:	P: 0.932 R: 0.748 F: 0.888
# 	|S| = 1 |T| = 2 |R| = 3
# Event 12:
# 	clue3d_to_sim:	P: 0.927 R: 0.207 F: 0.546
# 	target_to_sim:	P: 0.923 R: 0.505 F: 0.792
# 	reco_to_sim:	P: 0.924 R: 0.503 F: 0.791
# 	|S| = 1 |T| = 4 |R| = 4
# Event 13:
# 	No data
# Event 14:
# 	clue3d_to_sim:	P: 0.997 R: 0.718 F: 0.925
# 	target_to_sim:	P: 0.997 R: 0.756 F: 0.937
# 	reco_to_sim:	P: 0.997 R: 0.756 F: 0.937
# 	|S| = 1 |T| = 1 |R| = 1
# Event 15:
# 	clue3d_to_sim:	P: 0.993 R: 0.487 F: 0.822
# 	target_to_sim:	P: 0.994 R: 0.617 F: 0.886
# 	reco_to_sim:	P: 0.994 R: 0.608 F: 0.882
# 	|S| = 1 |T| = 1 |R| = 1
# Event 16:
# 	clue3d_to_sim:	P: 0.973 R: 0.680 F: 0.896
# 	target_to_sim:	P: 0.969 R: 0.733 F: 0.911
# 	reco_to_sim:	P: 0.972 R: 0.680 F: 0.895
# 	|S| = 1 |T| = 3 |R| = 4
# Event 17:
# 	No data
# Event 18:
# 	clue3d_to_sim:	P: 0.901 R: 0.454 F: 0.753
# 	target_to_sim:	P: 0.898 R: 0.572 F: 0.806
# 	reco_to_sim:	P: 0.901 R: 0.454 F: 0.753
# 	|S| = 1 |T| = 1 |R| = 1
# Event 19:
# 	clue3d_to_sim:	P: 0.768 R: 0.153 F: 0.426
# 	target_to_sim:	P: 0.735 R: 0.501 F: 0.672
# 	reco_to_sim:	P: 0.766 R: 0.403 F: 0.649
# 	|S| = 1 |T| = 1 |R| = 1
# -----
# mean clue3d_to_sim:	P: 0.778 R: 0.333 F: 0.562
# mean target_to_sim:	P: 0.771 R: 0.430 F: 0.626
# mean reco_to_sim:	P: 0.775 R: 0.388 F: 0.604
# mean n_tracksters:	P: 0.850 R: 1.550 F: 1.800
#  --- Radius threshold: 10 ---
# Event 0:
# 	clue3d_to_sim:	P: 0.802 R: 0.307 F: 0.607
# 	target_to_sim:	P: 0.761 R: 0.659 F: 0.738
# 	reco_to_sim:	P: 0.780 R: 0.380 F: 0.645
# 	|S| = 1 |T| = 3 |R| = 4
# Event 1:
# 	clue3d_to_sim:	P: 0.993 R: 0.335 F: 0.713
# 	target_to_sim:	P: 0.987 R: 0.413 F: 0.772
# 	reco_to_sim:	P: 0.987 R: 0.412 F: 0.771
# 	|S| = 1 |T| = 2 |R| = 2
# Event 2:
# 	clue3d_to_sim:	P: 0.955 R: 0.221 F: 0.573
# 	target_to_sim:	P: 0.936 R: 0.423 F: 0.754
# 	reco_to_sim:	P: 0.953 R: 0.408 F: 0.752
# 	|S| = 1 |T| = 2 |R| = 2
# Event 3:
# 	clue3d_to_sim:	P: 0.976 R: 0.793 F: 0.933
# 	target_to_sim:	P: 0.960 R: 0.823 F: 0.929
# 	reco_to_sim:	P: 0.976 R: 0.793 F: 0.933
# 	|S| = 1 |T| = 2 |R| = 2
# Event 4:
# 	clue3d_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	target_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	reco_to_sim:	P: 0.635 R: 0.595 F: 0.626
# 	|S| = 1 |T| = 1 |R| = 1
# Event 5:
# 	clue3d_to_sim:	P: 1.000 R: 0.511 F: 0.839
# 	target_to_sim:	P: 1.000 R: 0.538 F: 0.853
# 	reco_to_sim:	P: 1.000 R: 0.538 F: 0.853
# 	|S| = 1 |T| = 1 |R| = 1
# Event 6:
# 	clue3d_to_sim:	P: 0.971 R: 0.500 F: 0.817
# 	target_to_sim:	P: 0.934 R: 0.681 F: 0.870
# 	reco_to_sim:	P: 0.822 R: 0.655 F: 0.782
# 	|S| = 1 |T| = 2 |R| = 2
# Event 7:
# 	clue3d_to_sim:	P: 0.974 R: 0.353 F: 0.721
# 	target_to_sim:	P: 0.967 R: 0.545 F: 0.837
# 	reco_to_sim:	P: 0.976 R: 0.534 F: 0.837
# 	|S| = 1 |T| = 3 |R| = 3
# Event 8:
# 	clue3d_to_sim:	P: 0.881 R: 0.306 F: 0.640
# 	target_to_sim:	P: 0.816 R: 0.442 F: 0.698
# 	reco_to_sim:	P: 0.881 R: 0.399 F: 0.710
# 	|S| = 1 |T| = 1 |R| = 1
# Event 9:
# 	clue3d_to_sim:	P: 0.994 R: 0.095 F: 0.343
# 	target_to_sim:	P: 0.996 R: 0.371 F: 0.745
# 	reco_to_sim:	P: 0.995 R: 0.297 F: 0.677
# 	|S| = 1 |T| = 1 |R| = 1
# Event 10:
# 	clue3d_to_sim:	P: 0.976 R: 0.576 F: 0.857
# 	target_to_sim:	P: 0.972 R: 0.660 F: 0.888
# 	reco_to_sim:	P: 0.972 R: 0.660 F: 0.888
# 	|S| = 1 |T| = 1 |R| = 1
# Event 11:
# 	clue3d_to_sim:	P: 0.957 R: 0.679 F: 0.885
# 	target_to_sim:	P: 0.943 R: 0.888 F: 0.932
# 	reco_to_sim:	P: 0.904 R: 0.887 F: 0.901
# 	|S| = 1 |T| = 1 |R| = 1
# Event 12:
# 	clue3d_to_sim:	P: 0.928 R: 0.207 F: 0.547
# 	target_to_sim:	P: 0.875 R: 0.634 F: 0.813
# 	reco_to_sim:	P: 0.876 R: 0.647 F: 0.818
# 	|S| = 1 |T| = 2 |R| = 2
# Event 13:
# 	No data
# Event 14:
# 	clue3d_to_sim:	P: 0.997 R: 0.718 F: 0.925
# 	target_to_sim:	P: 0.992 R: 0.862 F: 0.963
# 	reco_to_sim:	P: 0.992 R: 0.862 F: 0.963
# 	|S| = 1 |T| = 1 |R| = 1
# Event 15:
# 	clue3d_to_sim:	P: 0.993 R: 0.487 F: 0.822
# 	target_to_sim:	P: 0.993 R: 0.727 F: 0.926
# 	reco_to_sim:	P: 0.993 R: 0.727 F: 0.926
# 	|S| = 1 |T| = 1 |R| = 1
# Event 16:
# 	clue3d_to_sim:	P: 0.973 R: 0.680 F: 0.896
# 	target_to_sim:	P: 0.956 R: 0.832 F: 0.929
# 	reco_to_sim:	P: 0.957 R: 0.782 F: 0.916
# 	|S| = 1 |T| = 1 |R| = 2
# Event 17:
# 	No data
# Event 18:
# 	clue3d_to_sim:	P: 0.901 R: 0.454 F: 0.753
# 	target_to_sim:	P: 0.800 R: 0.680 F: 0.773
# 	reco_to_sim:	P: 0.846 R: 0.521 F: 0.752
# 	|S| = 1 |T| = 1 |R| = 1
# Event 19:
# 	clue3d_to_sim:	P: 0.779 R: 0.160 F: 0.439
# 	target_to_sim:	P: 0.687 R: 0.647 F: 0.678
# 	reco_to_sim:	P: 0.771 R: 0.436 F: 0.668
# 	|S| = 1 |T| = 1 |R| = 1
# -----
# mean clue3d_to_sim:	P: 0.839 R: 0.399 F: 0.650
# mean target_to_sim:	P: 0.815 R: 0.571 F: 0.740
# mean reco_to_sim:	P: 0.816 R: 0.527 F: 0.721
# mean n_tracksters:	P: 0.900 R: 1.350 F: 1.450
#  --- Radius threshold: 15 ---
# Event 0:
# 	clue3d_to_sim:	P: 0.802 R: 0.307 F: 0.607
# 	target_to_sim:	P: 0.718 R: 0.727 F: 0.720
# 	reco_to_sim:	P: 0.777 R: 0.354 F: 0.627
# 	|S| = 1 |T| = 2 |R| = 4
# Event 1:
# 	clue3d_to_sim:	P: 0.993 R: 0.335 F: 0.713
# 	target_to_sim:	P: 0.984 R: 0.427 F: 0.780
# 	reco_to_sim:	P: 0.984 R: 0.426 F: 0.780
# 	|S| = 1 |T| = 2 |R| = 2
# Event 2:
# 	clue3d_to_sim:	P: 0.955 R: 0.221 F: 0.573
# 	target_to_sim:	P: 0.925 R: 0.430 F: 0.752
# 	reco_to_sim:	P: 0.947 R: 0.413 F: 0.752
# 	|S| = 1 |T| = 2 |R| = 2
# Event 3:
# 	clue3d_to_sim:	P: 0.976 R: 0.793 F: 0.933
# 	target_to_sim:	P: 0.960 R: 0.823 F: 0.929
# 	reco_to_sim:	P: 0.976 R: 0.793 F: 0.933
# 	|S| = 1 |T| = 2 |R| = 2
# Event 4:
# 	clue3d_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	target_to_sim:	P: 0.711 R: 0.633 F: 0.694
# 	reco_to_sim:	P: 0.727 R: 0.595 F: 0.696
# 	|S| = 1 |T| = 1 |R| = 1
# Event 5:
# 	clue3d_to_sim:	P: 1.000 R: 0.511 F: 0.839
# 	target_to_sim:	P: 1.000 R: 0.566 F: 0.867
# 	reco_to_sim:	P: 1.000 R: 0.538 F: 0.854
# 	|S| = 1 |T| = 1 |R| = 1
# Event 6:
# 	clue3d_to_sim:	P: 0.971 R: 0.500 F: 0.817
# 	target_to_sim:	P: 0.926 R: 0.691 F: 0.867
# 	reco_to_sim:	P: 0.929 R: 0.674 F: 0.864
# 	|S| = 1 |T| = 2 |R| = 2
# Event 7:
# 	clue3d_to_sim:	P: 0.974 R: 0.353 F: 0.721
# 	target_to_sim:	P: 0.967 R: 0.597 F: 0.860
# 	reco_to_sim:	P: 0.968 R: 0.590 F: 0.858
# 	|S| = 1 |T| = 2 |R| = 2
# Event 8:
# 	clue3d_to_sim:	P: 0.881 R: 0.306 F: 0.640
# 	target_to_sim:	P: 0.816 R: 0.442 F: 0.698
# 	reco_to_sim:	P: 0.838 R: 0.400 F: 0.687
# 	|S| = 1 |T| = 1 |R| = 1
# Event 9:
# 	clue3d_to_sim:	P: 0.994 R: 0.095 F: 0.343
# 	target_to_sim:	P: 0.996 R: 0.371 F: 0.745
# 	reco_to_sim:	P: 0.995 R: 0.297 F: 0.677
# 	|S| = 1 |T| = 1 |R| = 1
# Event 10:
# 	clue3d_to_sim:	P: 0.976 R: 0.576 F: 0.857
# 	target_to_sim:	P: 0.972 R: 0.660 F: 0.888
# 	reco_to_sim:	P: 0.949 R: 0.678 F: 0.879
# 	|S| = 1 |T| = 1 |R| = 1
# Event 11:
# 	clue3d_to_sim:	P: 0.957 R: 0.679 F: 0.885
# 	target_to_sim:	P: 0.943 R: 0.888 F: 0.932
# 	reco_to_sim:	P: 0.883 R: 0.897 F: 0.886
# 	|S| = 1 |T| = 1 |R| = 1
# Event 12:
# 	clue3d_to_sim:	P: 0.928 R: 0.207 F: 0.547
# 	target_to_sim:	P: 0.871 R: 0.637 F: 0.811
# 	reco_to_sim:	P: 0.849 R: 0.701 F: 0.815
# 	|S| = 1 |T| = 2 |R| = 1
# Event 13:
# 	clue3d_to_sim:	P: 0.999 R: 0.761 F: 0.940
# 	target_to_sim:	P: 1.000 R: 0.834 F: 0.962
# 	reco_to_sim:	P: 1.000 R: 0.834 F: 0.962
# 	|S| = 1 |T| = 1 |R| = 1
# Event 14:
# 	clue3d_to_sim:	P: 0.997 R: 0.718 F: 0.925
# 	target_to_sim:	P: 0.995 R: 0.902 F: 0.975
# 	reco_to_sim:	P: 0.995 R: 0.902 F: 0.975
# 	|S| = 1 |T| = 1 |R| = 1
# Event 15:
# 	clue3d_to_sim:	P: 0.993 R: 0.489 F: 0.823
# 	target_to_sim:	P: 0.993 R: 0.731 F: 0.927
# 	reco_to_sim:	P: 0.961 R: 0.727 F: 0.903
# 	|S| = 1 |T| = 2 |R| = 2
# Event 16:
# 	clue3d_to_sim:	P: 0.973 R: 0.680 F: 0.896
# 	target_to_sim:	P: 0.956 R: 0.832 F: 0.929
# 	reco_to_sim:	P: 0.943 R: 0.830 F: 0.918
# 	|S| = 1 |T| = 1 |R| = 1
# Event 17:
# 	No data
# Event 18:
# 	clue3d_to_sim:	P: 0.901 R: 0.454 F: 0.753
# 	target_to_sim:	P: 0.800 R: 0.680 F: 0.773
# 	reco_to_sim:	P: 0.829 R: 0.540 F: 0.749
# 	|S| = 1 |T| = 1 |R| = 1
# Event 19:
# 	clue3d_to_sim:	P: 0.782 R: 0.161 F: 0.441
# 	target_to_sim:	P: 0.674 R: 0.707 F: 0.680
# 	reco_to_sim:	P: 0.760 R: 0.478 F: 0.680
# 	|S| = 1 |T| = 2 |R| = 2
# -----
# mean clue3d_to_sim:	P: 0.889 R: 0.437 F: 0.697
# mean target_to_sim:	P: 0.860 R: 0.629 F: 0.789
# mean reco_to_sim:	P: 0.866 R: 0.583 F: 0.775
# mean n_tracksters:	P: 0.950 R: 1.400 F: 1.450

# %%
print("CLUE:", clue3D_F)
print("Target:", target_F)
print("Reco:", model_reco_F)
# Out:
# CLUE: [0.2660786195101392, 0.5618487610549607, 0.6503284712982198, 0.6974920132483364]
# Target: [0.2919276870410676, 0.6258355186302973, 0.7396882199913862, 0.7894303922179595]
# Reco: [0.2839844192276372, 0.603756619812702, 0.7209070767506977, 0.7746523994620464]

# %%
fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111)

ax.plot(r_ranges[:6], (np.array(target_F) - np.array(clue3D_F))[:6], '--s', label="target $\Delta F_{0.5}$", c="#D55E00")
ax.plot(r_ranges[:6], (np.array(model_reco_F) - np.array(clue3D_F))[:6], '-o', label="GNN LP $\Delta F_{0.5}$", c="#56B4E9")
# ax.plot(r_ranges[:6], (np.array(naive_reco_F) - np.array(clue3D_F))[:6], '-v', label="naive $\Delta F_{0.5}$", c="#E69F00")

ax.axhline(max(np.array(naive_reco_F) - np.array(clue3D_F)), label="baseline", c="lightgray", linestyle="--")

ax.legend()
ax.set_xlabel("Neighborhood radius (cm)")
ax.set_ylabel("$\Delta F_{0.5}$")
ax.set_ylim((-0.1, 0.1))

fig.savefig(f'export/{ds_name}-e5-graph-lp-de-radius-plot.png', dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# %%
print("Reco", max(np.array(model_reco_F) - np.array(clue3D_F)))
print("Naive", max(np.array(naive_reco_F) - np.array(clue3D_F)))
print("Target", max(np.array(target_F) - np.array(clue3D_F)))
# Out:
# Reco 0.07716038621371002
# Naive 0.017892120463903316
# Target 0.09193837896962309

# %% [markdown]
# ## Setup comparison:
#
# Pairwise:
# - mean clue3d_to_sim:	P: 0.994 R: 0.301 F: 0.652
# - mean target_to_sim:	P: 0.992 R: 0.689 F: 0.892
# - mean reco_to_sim:	    P: 0.659 R: 0.699 F: 0.642
#
# Graph (node-pred):
# - mean clue3d_to_sim:	P: 0.994 R: 0.301 F: 0.652
# - mean target_to_sim:	P: 0.992 R: 0.688 F: 0.892
# - mean reco_to_sim:	    P: 0.659 R: 0.699 F: 0.642
#
# Graph (link-pred):
# - mean clue3d_to_sim:	P: 0.994 R: 0.301 F: 0.652
# - mean target_to_sim:	P: 0.992 R: 0.689 F: 0.892
# - mean reco_to_sim:	P: 0.915 R: 0.329 F: 0.637

# %% [markdown]
# ## Results
#
# Using alpha=balance seems to converge faster (100 epochs rather than 200)
# - maybe just sticking to 0.25? (works just fine)
#
# Hyperparams
# - (64, 128, noskip), alpha=balance, roc_auc = 0.9733
# - (64, 128, 256fc, noskip, 200e), alpha=1-balance, roc_auc = 0.9771
# - (64, 128, 256fc, noskip, 200e), alpha=balance, roc_auc = 0.981
# - (64, 128, 256fc, noskip, 100e), alpha=0.25, roc_auc = 0.9796
