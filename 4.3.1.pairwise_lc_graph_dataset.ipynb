# %% [markdown]
# # Dataset: Pairwise GNN approach
#
# Get tracksters from a certain neighbourhood.
#
# Construct a graph of the neighbourgood (or just a binary pair?) based on layer-clusters.
#
# Classify cut-edges based on the node data.
# Node data is enriched using message passing.
#
# Maybe it's easier to start with binary pairs - although not computationaly optimal.
#
# Graph:
# - linked_inners
#     - nodes linked to the given tracksters within its cone

# %%
import uproot
import numpy as np
import awkward as ak
import networkx as nx

import matplotlib.pyplot as plt

from reco.event import get_candidate_pairs
from reco.graphs import create_graph
from reco.dataset import match_trackster_pairs, PointCloudPairs

from reco.plotting import plot_graph_3D


# plt.style.use('seaborn-whitegrid')
# data_root = "data/"
# raw_dir = "/Users/ecuba/data/multiparticle_complet"

data_root = "data"
ds_name = "CloseByTwoPion"
raw_dir = f"/Users/ecuba/data/{ds_name}"
file_name = f"{raw_dir}/new_ntuples_15101852_191.root"

# data_root = "/mnt/ceph/users/ecuba/processed"
# raw_dir = "/mnt/ceph/users/ecuba/multiparticle_10/"
# file_name = f"{raw_dir}/new_ntuples_14992862_1293.root"

tracksters = uproot.open({file_name: "ticlNtuplizer/tracksters"})
simtracksters = uproot.open({file_name: "ticlNtuplizer/simtrackstersSC"})
graphs = uproot.open({file_name: "ticlNtuplizer/graph"})
associations = uproot.open({file_name: "ticlNtuplizer/associations"})

# %%
eid = 0

c_pairs, dst_map = get_candidate_pairs(tracksters, graphs, eid, max_distance=15)

gt_pairs = match_trackster_pairs(
    tracksters,
    simtracksters,
    associations,
    eid,
    energy_threshold=20,
    distance_threshold=15,
)

# %% [markdown]
# build supergraph

# %%
vx = tracksters["vertices_x"].array()[eid]
vy = tracksters["vertices_y"].array()[eid]
vz = tracksters["vertices_z"].array()[eid]
ve = tracksters["vertices_energy"].array()[eid]
vi = tracksters["vertices_indexes"].array()[eid]


ca, cb, _ = gt_pairs[0] # c_pairs for candidate pairs

ca_lc = set(vi[ca])
cb_lc = set(vi[cb])

cvx = ak.flatten([vx[ca], vx[cb]])
cvy = ak.flatten([vy[ca], vy[cb]])
cvz = ak.flatten([vz[ca], vz[cb]])
cve = ak.flatten([ve[ca], ve[cb]])
cvi = ak.flatten([vi[ca], vi[cb]])

G = create_graph(cvx, cvy, cvz, cve, trk_lc_index=cvi, N=1, higher_e=True)

for edge in G.edges:
    a, b = edge
    ai = G.nodes[a]["index"]
    bi = G.nodes[b]["index"]
    if (ai in ca_lc and bi in cb_lc) or (bi in ca_lc and ai in cb_lc):
        G.edges[edge]["color"] = "green"

# %%
plot_graph_3D(G, cve)

# %% [markdown]
# # The dataset
#
# Following DGCNN, the graphs are constructed dynamically, therefore, the sample data should contain a two point clouds and a label.

# %%
ds = PointCloudPairs(
    ds_name,
    data_root,
    raw_dir,
    N_FILES=5,
    balanced=True,
    MAX_DISTANCE=15,
    ENERGY_THRESHOLD=20,
)
# Out:
# Processing: /Users/ecuba/data/CloseByTwoPion/new_ntuples_15101852_157.root
# Processing: /Users/ecuba/data/CloseByTwoPion/new_ntuples_15101852_229.root
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> ds = PointCloudPairs(
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     ds_name,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     data_root,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     raw_dir,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     N_FILES=20,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     balanced=True,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     MAX_DISTANCE=15,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     ENERGY_THRESHOLD=20,
#       <a href='vscode-notebook-cell:/Users/ecuba/devel/pattern-reco/4.3.1.pairwise_lc_graph_dataset.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> )
#
# File ~/devel/pattern-reco/reco/dataset.py:468, in PointCloudPairs.__init__(self, name, root_dir, raw_data_path, balanced, N_FILES, MAX_DISTANCE, ENERGY_THRESHOLD, padding)
#     465 fn = self.processed_paths[0]
#     467 if not path.exists(fn):
# --> 468     self.process()
#     470 dx1, dx2, dy = torch.load(fn)
#     471 self.x1 = dx1
#
# File ~/devel/pattern-reco/reco/dataset.py:552, in PointCloudPairs.process(self)
#     548 graph = uproot.open({source: "ticlNtuplizer/graph"})
#     550 for eid in range(len(tracksters["vertices_x"].array())):
# --> 552     candidate_pairs, _ = get_candidate_pairs(
#     553         tracksters,
#     554         graph,
#     555         eid,
#     556         max_distance=self.MAX_DISTANCE
#     557     )
#     559     gt_pairs = match_trackster_pairs(
#     560         tracksters,
#     561         simtracksters,
#    (...)
#     565         distance_threshold=self.MAX_DISTANCE,
#     566     )
#     568     ab_pairs = set([(a, b) for a, b, _ in gt_pairs])
#
# File ~/devel/pattern-reco/reco/event.py:124, in get_candidate_pairs(tracksters, graph, eid, max_distance)
#     122 def get_candidate_pairs(tracksters, graph, eid, max_distance=10):
#     123     vx = tracksters["vertices_x"].array()[eid]
# --> 124     vy = tracksters["vertices_y"].array()[eid]
#     125     vz = tracksters["vertices_z"].array()[eid]
#     126     clouds = [np.array([vx[tid], vy[tid], vz[tid]]).T for tid in range(len(vx))]
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:2078, in TBranch.array(self, interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library)
#    2072             for (
#    2073                 basket_num,
#    2074                 range_or_basket,
#    2075             ) in branch.entries_to_ranges_or_baskets(entry_start, entry_stop):
#    2076                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
# -> 2078 _ranges_or_baskets_to_arrays(
#    2079     self,
#    2080     ranges_or_baskets,
#    2081     branchid_interpretation,
#    2082     entry_start,
#    2083     entry_stop,
#    2084     decompression_executor,
#    2085     interpretation_executor,
#    2086     library,
#    2087     arrays,
#    2088     False,
#    2089 )
#    2091 _fix_asgrouped(
#    2092     arrays, expression_context, branchid_interpretation, library, None
#    2093 )
#    2095 if array_cache is not None:
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3496, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets)
#    3493     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3495 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
# -> 3496     interpretation_executor.submit(basket_to_array, obj)
#    3498 elif obj is None:
#    3499     pass
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/source/futures.py:73, in TrivialExecutor.submit(self, task, *args)
#      69 def submit(self, task, *args):
#      70     """
#      71     Immediately runs ``task(*args)``.
#      72     """
# ---> 73     return TrivialFuture(task(*args))
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3472, in _ranges_or_baskets_to_arrays.<locals>.basket_to_array(basket)
#    3469 basket = None
#    3471 if len(basket_arrays) == branchid_num_baskets[branch.cache_key]:
# -> 3472     arrays[branch.cache_key] = interpretation.final_array(
#    3473         basket_arrays,
#    3474         entry_start,
#    3475         entry_stop,
#    3476         branch.entry_offsets,
#    3477         library,
#    3478         branch,
#    3479     )
#    3480     # no longer needed, save memory
#    3481     basket_arrays.clear()
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/interpretation/objects.py:225, in AsObjects.final_array(self, basket_arrays, entry_start, entry_stop, entry_offsets, library, branch)
#     213     output = numpy.concatenate(trimmed)
#     215 self.hook_before_library_finalize(
#     216     basket_arrays=basket_arrays,
#     217     entry_start=entry_start,
#    (...)
#     222     output=output,
#     223 )
# --> 225 output = library.finalize(output, branch, self, entry_start, entry_stop)
#     227 self.hook_after_final_array(
#     228     basket_arrays=basket_arrays,
#     229     entry_start=entry_start,
#    (...)
#     234     output=output,
#     235 )
#     237 return output
#
# File ~/devel/ve/lib/python3.8/site-packages/uproot/interpretation/library.py:578, in Awkward.finalize(self, array, branch, interpretation, entry_start, entry_stop)
#     561     except uproot.interpretation.objects.CannotBeAwkward as err:
#     562         raise ValueError(
#     563             """cannot produce Awkward Arrays for interpretation {} because
#     564
#    (...)
#     575             )
#     576         )
# --> 578     unlabeled = awkward.from_iter(
#     579         (_object_to_awkward_json(form, x) for x in array), highlevel=False
#     580     )
#     581     return awkward.Array(_awkward_json_to_array(awkward, form, unlabeled))
#     583 elif array.dtype.names is not None:
#
# File ~/devel/ve/lib/python3.8/site-packages/awkward/operations/convert.py:891, in from_iter(iterable, highlevel, behavior, allow_record, initial, resize)
#     889 out = ak.layout.ArrayBuilder(initial=initial, resize=resize)
#     890 for x in iterable:
# --> 891     out.fromiter(x)
#     892 layout = out.snapshot()
#     893 return ak._util.maybe_wrap(layout, behavior, highlevel)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/abc.py:96, in ABCMeta.__instancecheck__(cls, instance)
#      90     """Register a virtual subclass of an ABC.
#      91
#      92     Returns the subclass, to allow usage as a class decorator.
#      93     """
#      94     return _abc_register(cls, subclass)
# ---> 96 def __instancecheck__(cls, instance):
#      97     """Override for isinstance(instance, cls)."""
#      98     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
len(ds[0][0])
# Out:
# 22

# %%
# pick a sample
x, labels = ds[0]

# remove padding (energy is 0)
truelen = min([i for i in range(len(x)) if x[i, 3] == 0] + [len(x)])
print(truelen)

x = x[:truelen]

# build the graph
G = create_graph(
    x[:,0].tolist(),
    x[:,1].tolist(),
    x[:,2].tolist(),
    x[:,3].tolist(),
    trk_lc_index=labels[:truelen],
    N=1,
    higher_e=True,
)

# color the cut edges
for edge in G.edges:
    a, b = edge
    if (G.nodes[a]["index"] != G.nodes[b]["index"]):
        G.edges[edge]["color"] = "red"

# plot it
plot_graph_3D(G, x[:,3])
# Out:
# 22

# %% [markdown]
# ## Padding
#
# The number of points in each sample needs to be constant.
#
# The padding doesn't really hurt as the padding nodes can be excluded from the knn and thus do not take part in the graph convolution.

# %%
lx = [len(sample[0]) for sample in ds]
max(lx)
# Out:
# 177

# %%
plt.hist(lx)
plt.yscale("log")
plt.show()
